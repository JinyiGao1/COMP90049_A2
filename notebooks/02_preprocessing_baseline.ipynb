# %% [markdown]
# # 02 Preprocessing and Baseline
#
# Build the target variable, patient-aware split, preprocessing pipeline, and first baseline model.

# %%
import pandas as pd
import numpy as np

from pathlib import Path
