# %% [markdown]
# # 05 Error and Subgroup Analysis
#
# Analyse false negatives and subgroup performance by age, race, and admission pathway.

# %%
import pandas as pd
import numpy as np

from pathlib import Path
