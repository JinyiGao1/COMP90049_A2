# %% [markdown]
# # 03 Classical Models
#
# Train and tune Logistic Regression, Naive Bayes, Decision Tree, Random Forest, and Gradient Boosting.

# %%
import pandas as pd
import numpy as np

from pathlib import Path
